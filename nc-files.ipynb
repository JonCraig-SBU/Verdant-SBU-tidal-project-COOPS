# %%
import xarray as xr
from pathlib import Path

# %%
base = Path(r"c:\Users\Hosse\Box\Projects\Verdant\data-analysis\Resource assesement\ADCP-jon\648\input")

rc = xr.open_dataset(base / "RC.nc")

dataset = {"RC": rc}
dataset
# Out:
# {'RC': <xarray.Dataset>
#  Dimensions:            (time: 7438, bin_depth: 9)
#  Coordinates:
#    * time               (time) datetime64[ns] 2010-08-02T21:59:03.750000 ... 2...
#  Dimensions without coordinates: bin_depth
#  Data variables: (12/17)
#      lat                float32 ...
#      lon                float32 ...
#      bin_height         (bin_depth) float32 ...
#      principal_profile  (bin_depth, time) float32 ...
#      depth              (time) float32 ...
#      nu                 float32 ...
#      ...                 ...
#      flood_idx_qs       (time) float32 ...
#      flood_idx_acc      (time) float32 ...
#      flood_idx_dec      (time) float32 ...
#      ebb_idx_qs         (time) float32 ...
#      ebb_idx_acc        (time) float32 ...
#      ebb_idx_dec        (time) float32 ...
#  Attributes:
#      title:        Processed data for The Race, New York, USA (Abbreviated as RC)
#      history:      Created on 2025-12-23 10:43:34
# ...
